# %%
# !pip install altair
# !pip install altair_viewer
# Out:
# ...
#    ---------------------------------------- 0.0/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/844.5 kB ? eta -:--:--
#    - -------------------------------------- 30.7/844.5 kB 45.2 kB/s eta 0:00:19
#    - -------------------------------------- 30.7/844.5 kB 45.2 kB/s eta 0:00:19
#    - -------------------------------------- 30.7/844.5 kB 45.2 kB/s eta 0:00:19
# ...
